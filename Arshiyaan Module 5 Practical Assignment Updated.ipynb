# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('coupons.csv')
df
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %%
df.describe() #gives us the statistical data analysis of the dataframe columns, that is, the mean, median, and std
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %%
df.info() #gives us the datatypes of the columns in the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
df.loc[df.duplicated()] #looks for any duplicates within the dataframe and then returns the duplicates
# Out:
#      destination passanger weather  temperature  time                 coupon  \
# 4192        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4236        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4280        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4324        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4409        Work     Alone   Sunny           80   7AM  Carry out & Take away
# ...          ...       ...     ...          ...   ...                    ...
# 8511        Home     Alone   Sunny           80   6PM                    Bar
# 8512        Home   Partner   Sunny           30  10PM  Carry out & Take away
# 8513        Work     Alone   Rainy           55   7AM        Restaurant(<20)
# 8515        Work     Alone   Snowy           30   7AM      Restaurant(20-50)
# 8516        Work     Alone   Sunny           80   7AM        Restaurant(<20)
#
# ...

# %%
df.isnull().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
df.drop('car', axis = 1) #removes the column named car
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %%
#Gives us a bar plot of both Accepted and Not Accepted Coupon by Venue
plt.figure(figsize=(10, 6))
sns.countplot(x='coupon', hue='Y', data=df)
plt.title('Coupon Acceptance by Coupon Type')
plt.show()

# %%
#Full Dataset Statistical Summary
print("Full Dataset Summary:")
print(df.describe())
# Out:
# Full Dataset Summary:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %%
#Displays statistical summaries and compare whether coupons are accepted vs when they are not excepted
accepted_summary = df[df['Y'] == 1].describe()
not_accepted_summary = df[df['Y'] == 0].describe()

print("Accepted Coupons Summary:")
print(accepted_summary)
print("Not Accepted Coupons Summary:")
print(not_accepted_summary)
# Out:
# Accepted Coupons Summary:
#        temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  7210.000000   7210.000000            7210.0        7210.000000
# mean     64.323856      0.394591               1.0           0.526214
# std      18.959363      0.488797               0.0           0.499347
# min      30.000000      0.000000               1.0           0.000000
# 25%      55.000000      0.000000               1.0           0.000000
# 50%      80.000000      0.000000               1.0           1.000000
# 75%      80.000000      1.000000               1.0           1.000000
# max      80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp       Y
# count        7210.000000     7210.000000    7210.000000  7210.0
# mean            0.089875        0.219972       0.780028     1.0
# std             0.286023        0.414256       0.414256     0.0
# ...

# %%
#Distribution of Coupon Types at Each Venue as a Pie Chart so we can see percentages
plt.figure(figsize=(8, 8))
coupon_counts = df['coupon'].value_counts()
plt.pie(coupon_counts, labels=coupon_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Coupon Types')
plt.show()

# %%
#These lines of code tell us the Probability of the Coupon being accepted as a Pie Chart
plt.figure(figsize=(16, 6))
plt.subplot(1, 3, 1)
coupon_acceptance_counts = df['Y'].value_counts()
labels_acceptance = ['Not Accepted', 'Accepted']
plt.pie(coupon_acceptance_counts, labels=labels_acceptance, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Coupon Acceptance')

#These lines of code tells us the Probability of the Coupon being accepted at each venue as a Pie Chart
plt.subplot(1, 3, 2)
accepted_coupon_types_counts = df[df['Y'] == 1]['coupon'].value_counts()
labels_accepted_types = accepted_coupon_types_counts.index
plt.pie(accepted_coupon_types_counts, labels=labels_accepted_types, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Coupon Types (Among Accepted Coupons)')

#These lines of code tells us the Probability of the Coupon not being accepted at each venue as a Pie Chart
plt.subplot(1, 3, 3)
not_accepted_coupon_types_counts = df[df['Y'] == 0]['coupon'].value_counts()
labels_not_accepted_types = not_accepted_coupon_types_counts.index
plt.pie(not_accepted_coupon_types_counts, labels=labels_not_accepted_types, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Coupon Types (Among Not Accepted Coupons)')

plt.tight_layout()
plt.show()

# %%
#Time of Day when Coupon is more likely to be accepted
plt.figure(figsize=(10, 6))
sns.barplot(x='Y', y='time', data=df)
plt.title('Average Current Time for Accepted and Not Accepted Coupons')
plt.xlabel('Accepted Coupon (0 = Not Accepted, 1 = Accepted)')
plt.ylabel('Current Time')
plt.show()

# %%
#Compares the which of the give venues has the highest and lowest amount of Coupon Acceptance 
plt.figure(figsize=(10, 6))
sns.countplot(x='coupon', data=df)
plt.title('Coupon Acceptance Comparison')
plt.show()

# %%
#Gives us a histogram plot which 0.0 means coupon is rejected and 1.0 means accepted
plt.figure(figsize=(10, 6))
sns.histplot(x='Y', hue='coupon', data=df, kde=True)
plt.title('Numerical Variable Distribution Comparison')
plt.show()
